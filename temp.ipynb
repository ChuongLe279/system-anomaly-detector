# %%
import psutil
import time

# %%
metrics = {
    "timestamp": time.time(),
    "cpu_percent": psutil.cpu_percent(),
    "mem_percent": psutil.virtual_memory().percent,
    "bytes_sent": psutil.net_io_counters().bytes_sent,
    "bytes_recv": psutil.net_io_counters().bytes_recv,
    "disk_read": psutil.disk_io_counters().read_bytes, # type: ignore
    "disk_write": psutil.disk_io_counters().write_bytes, # type: ignore
    "process_count": len(psutil.pids()),
}
metrics
# Out:
# {'timestamp': 1779327704.8674958,
#  'cpu_percent': 11.8,
#  'mem_percent': 85.0,
#  'bytes_sent': 51625172,
#  'bytes_recv': 1076846843,
#  'disk_read': 62225261568,
#  'disk_write': 49924622336,
#  'process_count': 381}
